# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
data = pd.read_csv(r"data/WHO_PM CLEANED.csv")

# %%
print(data.head())
print(data.dtypes)
print(data.describe())
# Out:
#      Region                                            Country  Year  \
# 0    Africa                                              Kenya  2019
# 1  Americas                                Trinidad and Tobago  2019
# 2    Europe  United Kingdom of Great Britain and Northern I...  2019
# 3  Americas                                            Grenada  2019
# 4  Americas                                             Brazil  2019
#
#    IsLatestYear Residence Area Type  FineParticulateMatterCount  \
# 0          True              Cities                       10.01
# 1          True               rural                       10.02
# 2          True              Cities                       10.06
# 3          True               Total                       10.08
# 4          True               Towns                       10.09
#
#    FineParticulateMatterLow  FineParticulateMatterHigh               Value
# 0                      6.29                      13.74  10.01 [6.29-13.74]
# 1                      7.44                      12.55  10.02 [7.44-12.55]
# 2                      9.73                      10.39  10.06 [9.73-10.39]
# 3                      7.07                      13.20  10.08 [7.07-13.20]
# 4                      8.23                      12.46  10.09 [8.23-12.46]
# Region                         object
# Country                        object
# Year                            int64
# IsLatestYear                     bool
# Residence Area Type            object
# FineParticulateMatterCount    float64
# FineParticulateMatterLow      float64
# FineParticulateMatterHigh     float64
# Value                          object
# dtype: object
#               Year  FineParticulateMatterCount  FineParticulateMatterLow  \
# count  9450.000000                 9450.000000               9450.000000
# mean   2014.500000                   23.538435                 16.229705
# std       2.872433                   15.024029                 11.174679
# min    2010.000000                    4.590000                  1.410000
# 25%    2012.000000                   11.920000                  7.850000
# 50%    2014.500000                   19.570000                 13.790000
# 75%    2017.000000                   30.977500                 20.340000
# max    2019.000000                   97.490000                 70.240000
#
#        FineParticulateMatterHigh
# count                9450.000000
# mean                   35.475423
# std                    27.150003
# min                     5.260000
# 25%                    15.950000
# 50%                    24.480000
# 75%                    49.687500
# max                   175.600000

# %%
print(data.isnull().sum())
data_clean = data.dropna()
print(data_clean.info())
# Out:
# Region                        0
# Country                       0
# Year                          0
# IsLatestYear                  0
# Residence Area Type           0
# FineParticulateMatterCount    0
# FineParticulateMatterLow      0
# FineParticulateMatterHigh     0
# Value                         0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9450 entries, 0 to 9449
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Region                      9450 non-null   object
#  1   Country                     9450 non-null   object
#  2   Year                        9450 non-null   int64
#  3   IsLatestYear                9450 non-null   bool
#  4   Residence Area Type         9450 non-null   object
#  5   FineParticulateMatterCount  9450 non-null   float64
#  6   FineParticulateMatterLow    9450 non-null   float64
#  7   FineParticulateMatterHigh   9450 non-null   float64
#  8   Value                       9450 non-null   object
# dtypes: bool(1), float64(3), int64(1), object(4)
# memory usage: 600.0+ KB
# None

# %%
# Visualization: Distribution of Fine Particulate Matter (PM2.5) Levels
plt.figure(figsize=(10, 6))
sns.histplot(data_clean['FineParticulateMatterCount'], kde=True, bins=30)
plt.title('Distribution of Fine Particulate Matter (PM2.5) Levels')
plt.xlabel('Fine Particulate Matter (PM2.5) Count')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualization: Box Plot by Region: Compares PM2.5 levels across different regions
plt.figure(figsize=(12, 6))
sns.boxplot(x='Region', y='FineParticulateMatterCount', data=data_clean)
plt.title('PM2.5 Levels by Region')
plt.xlabel('Region')
plt.ylabel('Fine Particulate Matter (PM2.5) Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualization: Time Series of PM2.5 Levels: Displays trends in PM2.5 levels over time by region
plt.figure(figsize=(14, 7))
sns.lineplot(x='Year', y='FineParticulateMatterCount', hue='Region', data=data_clean)
plt.title('PM2.5 Levels Over Time by Region')
plt.xlabel('Year')
plt.ylabel('Fine Particulate Matter (PM2.5) Count')
plt.show()

# %%
# Correlation matrix: Displays correlations between numerical fields using a heatmap
correlation_matrix = data_clean.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
